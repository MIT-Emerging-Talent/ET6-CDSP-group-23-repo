# %% [markdown]
# # **Data Exploration for "pre_transfer_labeled_clean_cv" and "post_transfer_labeled_clean_cv" datasets.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load Data
pre = pd.read_csv("1_datasets/pre_transfer_cleaned.csv")
post = pd.read_csv("1_datasets/post_transfer_cleaned.csv")

# %% [markdown]
# ## 🔎 Initial Look at the Data

# %%
# Have a look at first 5 rows
pre.head()
# Out:
#       Player Name  Average Rating  Defending - Aerial duels won  \
# 0    Aaron Lennon            6.58                          0.20
# 1      Aaron Mooy            6.99                          0.77
# 2  Adam Armstrong            7.00                          0.32
# 3    Adam Webster            7.08                          6.28
# 4    Adama Traore            7.22                          1.12
#
#    Defending - Blocked  Defending - Dribbled past  Defending - Duels won  \
# 0                 0.26                       0.74                   4.07
# 1                 0.49                       1.07                   4.56
# 2                 1.09                       0.39                   2.89
# 3                 0.31                       0.38                   9.30
# 4                 0.39                       0.57                  14.36
#
#    Defending - Fouls committed  Defending - Interceptions  \
# 0                         1.42                       1.06
# ...

# %%
# Have a look at first 5 rows
post.head()
# Out:
#       Player Name  Average Rating  Defending - Aerial duels won  \
# 0    Aaron Lennon            6.58                          0.41
# 1      Aaron Mooy            6.86                          0.65
# 2  Adam Armstrong            6.66                          0.58
# 3    Adam Webster            6.94                          3.20
# 4    Adama Traore            7.10                          1.89
#
#    Defending - Blocked  Defending - Dribbled past  Defending - Duels won  \
# 0                 0.23                       1.40                   4.24
# 1                 0.34                       1.46                   4.35
# 2                 0.64                       0.42                   2.82
# 3                 0.10                       0.53                   5.26
# 4                 0.51                       0.51                  12.34
#
#    Defending - Fouls committed  Defending - Interceptions  \
# 0                         1.10                       0.52
# ...

# %%
# Have a look at last 5 rows
pre.tail()
# Out:
#             Player Name  Average Rating  Defending - Aerial duels won  \
# 143         Tyler Adams            6.85                          1.18
# 144      Tyrell Malacia            6.98                          0.72
# 145  Victor Kristiansen            6.70                          0.68
# 146     Wilfried Gnonto            6.78                          0.82
# 147          Willy Boly            7.24                          2.74
#
#      Defending - Blocked  Defending - Dribbled past  Defending - Duels won  \
# 143                 0.09                       0.94                   4.80
# 144                 0.36                       0.84                   5.65
# 145                 0.36                       0.88                   3.92
# 146                 0.68                       0.97                   8.78
# 147                 0.22                       0.63                   6.33
#
#      Defending - Fouls committed  Defending - Interceptions  \
# ...

# %%
# Have a look at last 5 rows
post.tail()
# Out:
#             Player Name  Average Rating  Defending - Aerial duels won  \
# 143         Tyler Adams            6.92                          1.31
# 144      Tyrell Malacia            6.86                          0.52
# 145  Victor Kristiansen            6.88                          0.92
# 146     Wilfried Gnonto            6.87                          0.48
# 147          Willy Boly            7.01                          3.91
#
#      Defending - Blocked  Defending - Dribbled past  Defending - Duels won  \
# 143                 0.22                       0.98                   7.18
# 144                 0.13                       0.71                   4.72
# 145                 0.09                       0.70                   5.00
# 146                 0.76                       1.08                   6.48
# 147                 0.10                       0.72                   7.16
#
#      Defending - Fouls committed  Defending - Interceptions  \
# ...

# %%
# Have a look random 5 rows
pre.sample(5)
# Out:
#         Player Name  Average Rating  Defending - Aerial duels won  \
# 53     Flynn Downes            6.91                          1.23
# 124    Raul Jimenez            7.04                          3.45
# 121  Philip Billing            7.00                          3.29
# 24     Borja Baston            6.61                          2.72
# 77      Josh Bowler            6.69                          0.03
#
#      Defending - Blocked  Defending - Dribbled past  Defending - Duels won  \
# 53                  0.26                       0.62                   5.99
# 124                 0.81                       0.38                   6.58
# 121                 0.41                       1.32                   7.87
# 24                  0.37                       1.27                   4.62
# 77                  0.92                       1.18                   6.50
#
#      Defending - Fouls committed  Defending - Interceptions  \
# ...

# %%
# Have a look random 5 rows
post.sample(5)
# Out:
#            Player Name  Average Rating  Defending - Aerial duels won  \
# 23          Bobby Reid            6.76                          0.70
# 91   Lisandro Martinez            6.92                          0.96
# 84  Keane Lewis Potter            6.76                          1.04
# 15      Arnaut Danjuma            6.84                          0.29
# 33           Che Adams            6.78                          2.58
#
#     Defending - Blocked  Defending - Dribbled past  Defending - Duels won  \
# 23                 0.64                       0.56                   4.59
# 91                 0.25                       0.76                   3.80
# 84                 0.74                       0.64                   4.06
# 15                 0.54                       0.36                   4.46
# 33                 0.74                       0.30                   6.01
#
#     Defending - Fouls committed  Defending - Interceptions  \
# ...

# %%
# (Rows sum, columns sum)
pre.shape
# Out:
# (148, 31)

# %%
# (Rows sum, columns sum)
post.shape
# Out:
# (148, 31)

# %%
# Metadata
pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 31 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Player Name                             148 non-null    object
#  1   Average Rating                          148 non-null    float64
#  2   Defending - Aerial duels won            148 non-null    float64
#  3   Defending - Blocked                     148 non-null    float64
#  4   Defending - Dribbled past               148 non-null    float64
#  5   Defending - Duels won                   148 non-null    float64
#  6   Defending - Fouls committed             148 non-null    float64
#  7   Defending - Interceptions               148 non-null    float64
#  8   Defending - Penalties conceded          148 non-null    float64
#  9   Defending - Possession won final 3rd    148 non-null    float64
# ...

# %%
# Metadata
post.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 31 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Player Name                             148 non-null    object
#  1   Average Rating                          148 non-null    float64
#  2   Defending - Aerial duels won            148 non-null    float64
#  3   Defending - Blocked                     148 non-null    float64
#  4   Defending - Dribbled past               148 non-null    float64
#  5   Defending - Duels won                   148 non-null    float64
#  6   Defending - Fouls committed             148 non-null    float64
#  7   Defending - Interceptions               148 non-null    float64
#  8   Defending - Penalties conceded          148 non-null    float64
#  9   Defending - Possession won final 3rd    148 non-null    float64
# ...

# %%
# List of columns names
pre.columns
# Out:
# Index(['Player Name', 'Average Rating', 'Defending - Aerial duels won',
#        'Defending - Blocked', 'Defending - Dribbled past',
#        'Defending - Duels won', 'Defending - Fouls committed',
#        'Defending - Interceptions', 'Defending - Penalties conceded',
#        'Defending - Possession won final 3rd', 'Defending - Recoveries',
#        'Defending - Tackles won', 'Discipline - Red cards',
#        'Discipline - Yellow cards', 'Minutes Played',
#        'Passing - Accurate long balls', 'Passing - Assists',
#        'Passing - Chances created', 'Passing - Successful crosses',
#        'Passing - Successful passes', 'Possession - Dispossessed',
#        'Possession - Fouls won', 'Possession - Penalties awarded',
#        'Possession - Successful dribbles', 'Possession - Touches',
#        'Possession - Touches in opposition box', 'ShootingRank - Goals',
#        'ShootingRank - Shots', 'ShootingRank - Shots on target', 'Season_Year',
#        'Position'],
# ...

# %%
# List of columns names
post.columns
# Out:
# Index(['Player Name', 'Average Rating', 'Defending - Aerial duels won',
#        'Defending - Blocked', 'Defending - Dribbled past',
#        'Defending - Duels won', 'Defending - Fouls committed',
#        'Defending - Interceptions', 'Defending - Penalties conceded',
#        'Defending - Possession won final 3rd', 'Defending - Recoveries',
#        'Defending - Tackles won', 'Discipline - Red cards',
#        'Discipline - Yellow cards', 'Minutes Played',
#        'Passing - Accurate long balls', 'Passing - Assists',
#        'Passing - Chances created', 'Passing - Successful crosses',
#        'Passing - Successful passes', 'Possession - Dispossessed',
#        'Possession - Fouls won', 'Possession - Penalties awarded',
#        'Possession - Successful dribbles', 'Possession - Touches',
#        'Possession - Touches in opposition box', 'ShootingRank - Goals',
#        'ShootingRank - Shots', 'ShootingRank - Shots on target', 'Season_Year',
#        'Position'],
# ...

# %% [markdown]
# 🧼 3. Check for Missing Values & Duplicates

# %%
# Check for missing Values
pre.isnull().sum()
# Out:
# Player Name                               0
# Average Rating                            0
# Defending - Aerial duels won              0
# Defending - Blocked                       0
# Defending - Dribbled past                 0
# Defending - Duels won                     0
# Defending - Fouls committed               0
# Defending - Interceptions                 0
# Defending - Penalties conceded            0
# Defending - Possession won final 3rd      0
# Defending - Recoveries                    0
# Defending - Tackles won                   0
# Discipline - Red cards                    0
# Discipline - Yellow cards                 0
# Minutes Played                            0
# Passing - Accurate long balls             0
# Passing - Assists                         0
# Passing - Chances created                 0
# Passing - Successful crosses              0
# Passing - Successful passes               0
# Possession - Dispossessed                 0
# ...

# %%
# Check for missing Values
post.isnull().sum()
# Out:
# Player Name                               0
# Average Rating                            0
# Defending - Aerial duels won              0
# Defending - Blocked                       0
# Defending - Dribbled past                 0
# Defending - Duels won                     0
# Defending - Fouls committed               0
# Defending - Interceptions                 0
# Defending - Penalties conceded            0
# Defending - Possession won final 3rd      0
# Defending - Recoveries                    0
# Defending - Tackles won                   0
# Discipline - Red cards                    0
# Discipline - Yellow cards                 0
# Minutes Played                            0
# Passing - Accurate long balls             0
# Passing - Assists                         0
# Passing - Chances created                 0
# Passing - Successful crosses              0
# Passing - Successful passes               0
# Possession - Dispossessed                 0
# ...

# %%
# Check for Duplicates
pre.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check for Duplicates
post.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##📈 Statistical Summary

# %%
# Statistical Summary for all the columns
pre.describe(include="all")
# Out:
#          Player Name  Average Rating  Defending - Aerial duels won  \
# count            148      148.000000                    148.000000
# unique           148             NaN                           NaN
# top     Aaron Lennon             NaN                           NaN
# freq               1             NaN                           NaN
# mean             NaN        6.965068                      1.931149
# std              NaN        0.209049                      1.671773
# min              NaN        6.580000                      0.030000
# 25%              NaN        6.820000                      0.835000
# 50%              NaN        6.940000                      1.485000
# 75%              NaN        7.060000                      2.515000
# max              NaN        7.640000                     13.330000
#
#         Defending - Blocked  Defending - Dribbled past  Defending - Duels won  \
# count            148.000000                 148.000000             148.000000
# ...

# %%
# Statistical Summary for all the columns
post.describe(include="all")
# Out:
#          Player Name  Average Rating  Defending - Aerial duels won  \
# count            148      148.000000                    148.000000
# unique           148             NaN                           NaN
# top     Aaron Lennon             NaN                           NaN
# freq               1             NaN                           NaN
# mean             NaN        6.848784                      1.685743
# std              NaN        0.186507                      1.391276
# min              NaN        6.350000                      0.100000
# 25%              NaN        6.720000                      0.775000
# 50%              NaN        6.830000                      1.280000
# 75%              NaN        6.942500                      2.170000
# max              NaN        7.700000                      9.000000
#
#         Defending - Blocked  Defending - Dribbled past  Defending - Duels won  \
# count            148.000000                 148.000000             148.000000
# ...

# %%
# Statistical Summary for the Average Rating column
pre["Average Rating"].describe()
# Out:
# count    148.000000
# mean       6.965068
# std        0.209049
# min        6.580000
# 25%        6.820000
# 50%        6.940000
# 75%        7.060000
# max        7.640000
# Name: Average Rating, dtype: float64

# %%
# Statistical Summary for the Average Rating column
post["Average Rating"].describe()
# Out:
# count    148.000000
# mean       6.848784
# std        0.186507
# min        6.350000
# 25%        6.720000
# 50%        6.830000
# 75%        6.942500
# max        7.700000
# Name: Average Rating, dtype: float64

# %% [markdown]
# ##📊 Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualization style
sns.set(style="whitegrid")

# 1. Distribution of Average Rating (Pre vs Post Transfer)
plt.figure(figsize=(12, 5))
sns.histplot(
    pre["Average Rating"], kde=True, color="blue", label="Pre Transfer", stat="density"
)
sns.histplot(
    post["Average Rating"],
    kde=True,
    color="green",
    label="Post Transfer",
    stat="density",
)
plt.title("Distribution of Average Rating (Pre vs Post Transfer)")
plt.xlabel("Average Rating")
plt.legend()
plt.tight_layout()
plt.show()
